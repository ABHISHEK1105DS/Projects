# %% [markdown]
# ### Importing required Libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from nltk.corpus import stopwords
from nltk.util import ngrams
from sklearn.feature_extraction.text import CountVectorizer
from collections import defaultdict
from collections import  Counter
plt.style.use('ggplot')
stop=set(stopwords.words('english'))
import re
from nltk.tokenize import word_tokenize
import gensim
import string
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tqdm import tqdm
from keras.models import Sequential
from keras.layers import Embedding,LSTM,Dense,SpatialDropout1D
from keras.initializers import Constant
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
import os
#os.listdir('../input/glove-global-vectors-for-word-representation/glove.6B.100d.txt')

# %% [markdown]
# ## Loading the data and getting basic idea

# %%
tweet= pd.read_csv('../input/nlp-getting-started/train.csv')
test=pd.read_csv('../input/nlp-getting-started/test.csv')
tweet.head(3)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
#
#    target
# 0       1
# 1       1
# 2       1

# %%
print('There are {} rows and {} columns in train'.format(tweet.shape[0],tweet.shape[1]))
print('There are {} rows and {} columns in train'.format(test.shape[0],test.shape[1]))
# Out:
# There are 7613 rows and 5 columns in train
# There are 3263 rows and 4 columns in train

# %% [markdown]
# ## Class distribution

# %% [markdown]
# Before we begin with anything else,let's check the class distribution.There are only two classes 0 and 1.

# %%
x=tweet.target.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('samples')
# Out:
# Text(0, 0.5, 'samples')

# %% [markdown]
# ohh,as expected ! There is a class distribution.There are more tweets with class 0 ( No disaster) than class 1 ( disaster tweets)

# %% [markdown]
# ## Exploratory Data Analysis of tweets

# %% [markdown]
# First,we will do very basic analysis,that is character level,word level and sentence level analysis.

# %% [markdown]
# ### Number of characters in tweets

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))
tweet_len=tweet[tweet['target']==1]['text'].str.len()
ax1.hist(tweet_len,color='red')
ax1.set_title('disaster tweets')
tweet_len=tweet[tweet['target']==0]['text'].str.len()
ax2.hist(tweet_len,color='green')
ax2.set_title('Not disaster tweets')
fig.suptitle('Characters in tweets')
plt.show()

# %% [markdown]
# The distribution of both seems to be almost same.120 t0 140 characters in a tweet are the most common among both.

# %% [markdown]
# ### Number of words in a tweet

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))
tweet_len=tweet[tweet['target']==1]['text'].str.split().map(lambda x: len(x))
ax1.hist(tweet_len,color='red')
ax1.set_title('disaster tweets')
tweet_len=tweet[tweet['target']==0]['text'].str.split().map(lambda x: len(x))
ax2.hist(tweet_len,color='green')
ax2.set_title('Not disaster tweets')
fig.suptitle('Words in a tweet')
plt.show()

# %% [markdown]
# ###  Average word length in a tweet

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5))
word=tweet[tweet['target']==1]['text'].str.split().apply(lambda x : [len(i) for i in x])
sns.distplot(word.map(lambda x: np.mean(x)),ax=ax1,color='red')
ax1.set_title('disaster')
word=tweet[tweet['target']==0]['text'].str.split().apply(lambda x : [len(i) for i in x])
sns.distplot(word.map(lambda x: np.mean(x)),ax=ax2,color='green')
ax2.set_title('Not disaster')
fig.suptitle('Average word length in each tweet')
# Out:
# Text(0.5, 0.98, 'Average word length in each tweet')

# %%
def create_corpus(target):
    corpus=[]
    
    for x in tweet[tweet['target']==target]['text'].str.split():
        for i in x:
            corpus.append(i)
    return corpus

# %% [markdown]
# ### Common stopwords in tweets

# %% [markdown]
# First we  will analyze tweets with class 0.

# %%
corpus=create_corpus(0)

dic=defaultdict(int)
for word in corpus:
    if word in stop:
        dic[word]+=1
        
top=sorted(dic.items(), key=lambda x:x[1],reverse=True)[:10]

# %%
x,y=zip(*top)
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Now,we will analyze tweets with class 1.

# %%
corpus=create_corpus(1)

dic=defaultdict(int)
for word in corpus:
    if word in stop:
        dic[word]+=1

top=sorted(dic.items(), key=lambda x:x[1],reverse=True)[:10] 
    


x,y=zip(*top)
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# In both of them,"the" dominates which is followed by "a" in class 0 and "in" in class 1.

# %% [markdown]
# ### Analyzing punctuations.

# %% [markdown]
# First let's check tweets indicating real disaster.

# %%
plt.figure(figsize=(10,5))
corpus=create_corpus(1)

dic=defaultdict(int)
import string
special = string.punctuation
for i in (corpus):
    if i in special:
        dic[i]+=1
        
x,y=zip(*dic.items())
plt.bar(x,y)
# Out:
# <BarContainer object of 18 artists>

# %% [markdown]
# Now,we will move on to class 0.

# %%
plt.figure(figsize=(10,5))
corpus=create_corpus(0)

dic=defaultdict(int)
import string
special = string.punctuation
for i in (corpus):
    if i in special:
        dic[i]+=1
        
x,y=zip(*dic.items())
plt.bar(x,y,color='green')
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# ### Common words ?

# %%
counter=Counter(corpus)
most=counter.most_common()
x=[]
y=[]
for word,count in most[:40]:
    if (word not in stop) :
        x.append(word)
        y.append(count)

# %%
sns.barplot(x=y,y=x)

# %% [markdown]
# Lot of cleaning needed !

# %% [markdown]
# ### Ngram analysis

# %% [markdown]
# we will do a bigram (n=2) analysis over the tweets.Let's check the most common bigrams in tweets.

# %%
def get_top_tweet_bigrams(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
plt.figure(figsize=(10,5))
top_tweet_bigrams=get_top_tweet_bigrams(tweet['text'])[:10]
x,y=map(list,zip(*top_tweet_bigrams))
sns.barplot(x=y,y=x)

# %% [markdown]
# We will need lot of cleaning here..

# %% [markdown]
# ## Data Cleaning
# As we know,twitter tweets always have to be cleaned before we go onto modelling.So we will do some basic cleaning such as spelling correction,removing punctuations,removing html tags and emojis etc.So let's start.

# %%
df=pd.concat([tweet,test])
df.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# (10876, 5)

# %% [markdown]
# ### Removing urls

# %%
example="New competition launched :https://www.kaggle.com/c/nlp-getting-started"

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

remove_URL(example)
# Out:
# 'New competition launched :'

# %%
df['text']=df['text'].apply(lambda x : remove_URL(x))

# %% [markdown]
# ### Removing HTML tags

# %%
example = """<div>
<h1>Real or Fake</h1>
<p>Kaggle </p>
<a href="https://www.kaggle.com/c/nlp-getting-started">getting started</a>
</div>"""

# %%
def remove_html(text):
    html=re.compile(r'<.*?>')
    return html.sub(r'',text)
print(remove_html(example))
# Out:
# Real or Fake
# Kaggle
# getting started

# %%
df['text']=df['text'].apply(lambda x : remove_html(x))

# %% [markdown]
# ### Romoving Emojis

# %%
# Reference : https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

remove_emoji("Omg another Earthquake 😔😔")
# Out:
# 'Omg another Earthquake '

# %%
df['text']=df['text'].apply(lambda x: remove_emoji(x))

# %% [markdown]
# ### Removing punctuations

# %%
def remove_punct(text):
    table=str.maketrans('','',string.punctuation)
    return text.translate(table)

example="I am a #king"
print(remove_punct(example))
# Out:
# I am a king

# %%
df['text']=df['text'].apply(lambda x : remove_punct(x))

# %% [markdown]
# ### Spelling Correction

# %% [markdown]
# Even if I'm not good at spelling I can correct it with python :) I will use `pyspellcheker` to do that.

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading https://files.pythonhosted.org/packages/6f/9d/5bb403decde661abc6c5467319a0729d7c238e04d8217d9fef885510ec9d/pyspellchecker-0.5.6-py2.py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 867kB/s eta 0:00:01
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.5.6

# %%
from spellchecker import SpellChecker

spell = SpellChecker()
def correct_spellings(text):
    corrected_text = []
    misspelled_words = spell.unknown(text.split())
    for word in text.split():
        if word in misspelled_words:
            corrected_text.append(spell.correction(word))
        else:
            corrected_text.append(word)
    return " ".join(corrected_text)
        
text = "corect me plese"
correct_spellings(text)
# Out:
# 'correct me plese'

# %%
#df['text']=df['text'].apply(lambda x : correct_spellings(x)#)

# %% [markdown]
# ## GloVe for Vectorization

# %% [markdown]
# Here we will use GloVe pretrained corpus model to represent our words.It is available in 3 varieties :50D ,100D and 200 Dimentional.We will try 100 D here.

# %%
def create_corpus(df):
    corpus=[]
    for tweet in tqdm(df['text']):
        words=[word.lower() for word in word_tokenize(tweet) if((word.isalpha()==1) & (word not in stop))]
        corpus.append(words)
    return corpus

# %%
corpus=create_corpus(df)
# Out:
# 100%|██████████| 10876/10876 [00:02<00:00, 3899.11it/s]

# %%
corpus
# Out:
# [['our', 'deeds', 'reason', 'earthquake', 'may', 'allah', 'forgive', 'us'],
#  ['forest', 'fire', 'near', 'la', 'ronge', 'sask', 'canada'],
#  ['all',
#   'residents',
#   'asked',
#   'shelter',
#   'place',
#   'notified',
#   'officers',
#   'no',
#   'evacuation',
#   'shelter',
#   'place',
#   'orders',
#   'expected'],
#  ['people', 'receive', 'wildfires', 'evacuation', 'orders', 'california'],
#  ['just',
#   'got',
#   'sent',
#   'photo',
#   'ruby',
#   'alaska',
#   'smoke',
#   'wildfires',
#   'pours',
#   'school'],
#  ['rockyfire',
#   'update',
#   'california',
#   'hwy',
#   'closed',
#   'directions',
#   'due',
#   'lake',
#   'county',
#   'fire',
#   'cafire',
#   'wildfires'],
#  ['flood',
#   'disaster',
#   'heavy',
#   'rain',
#   'causes',
#   'flash',
#   'flooding',
#   'streets',
#   'manitou',
#   'colorado',
#   'springs',
#   'areas'],
#  ['im', 'top', 'hill', 'i', 'see', 'fire', 'woods'],
#  ['theres',
#   'emergency',
#   'evacuation',
#   'happening',
#   'building',
#   'across',
#   'street'],
#  ['im', 'afraid', 'tornado', 'coming', 'area'],
#  ['three', 'people', 'died', 'heat', 'wave', 'far'],
#  ['haha',
#   'south',
#   'tampa',
#   'getting',
#   'flooded',
#   'hah',
#   'wait',
#   'a',
#   'second',
#   'i',
#   'live',
#   'in',
#   'south',
#   'tampa',
#   'what',
#   'am',
#   'i',
#   'gon',
#   'na',
#   'do',
#   'what',
#   'am',
#   'i',
#   'gon',
#   'na',
#   'do',
#   'fvck',
#   'flooding'],
#  ['raining',
#   'flooding',
#   'florida',
#   'tampabay',
#   'tampa',
#   'days',
#   'ive',
#   'lost',
#   'count'],
#  ['flood', 'bago', 'myanmar', 'we', 'arrived', 'bago'],
#  ['damage', 'school', 'bus', 'multi', 'car', 'crash', 'breaking'],
#  ['whats', 'man'],
#  ['i', 'love', 'fruits'],
#  ['summer', 'lovely'],
#  ['my', 'car', 'fast'],
#  ['what', 'goooooooaaaaaal'],
#  ['ridiculous'],
#  ['london', 'cool'],
#  ['love', 'skiing'],
#  ['what', 'wonderful', 'day'],
#  ['looooool'],
#  ['no', 'wayi', 'cant', 'eat', 'shit'],
#  ['was', 'nyc', 'last', 'week'],
#  ['love', 'girlfriend'],
#  ['cooool'],
#  ['do', 'like', 'pasta'],
#  ['the', 'end'],
#  ['bbcmtd', 'wholesale', 'markets', 'ablaze'],
#  ['we', 'always', 'try', 'bring', 'heavy', 'metal', 'rt'],
#  ['africanbaze', 'breaking', 'newsnigeria', 'flag', 'set', 'ablaze', 'aba'],
#  ['crying', 'set', 'ablaze'],
#  ['on',
#   'plus',
#   'side',
#   'look',
#   'at',
#   'the',
#   'sky',
#   'last',
#   'night',
#   'it',
#   'was',
#   'ablaze'],
#  ['phdsquares',
#   'mufc',
#   'theyve',
#   'built',
#   'much',
#   'hype',
#   'around',
#   'new',
#   'acquisitions',
#   'i',
#   'doubt',
#   'set',
#   'epl',
#   'ablaze',
#   'season'],
#  ['inec', 'office', 'abia', 'set', 'ablaze'],
#  ['barbados',
#   'bridgetown',
#   'jamaica',
#   'two',
#   'cars',
#   'set',
#   'ablaze',
#   'santa',
#   'cruz',
#   'head',
#   'st',
#   'elizabeth',
#   'police',
#   'superintende'],
#  ['ablaze', 'lord', 'd'],
#  ['check', 'nsfw'],
#  ['outside', 'youre', 'ablaze', 'alive', 'youre', 'dead', 'inside'],
#  ['had',
#   'awesome',
#   'time',
#   'visiting',
#   'cfc',
#   'head',
#   'office',
#   'ancop',
#   'site',
#   'ablaze',
#   'thanks',
#   'tita',
#   'vida',
#   'taking',
#   'care',
#   'us'],
#  ['soooo', 'pumped', 'for', 'ablaze', 'southridgelife'],
#  ['i', 'wanted', 'set', 'chicago', 'ablaze', 'preaching', 'but', 'hotel'],
#  ['i', 'gained', 'followers', 'last', 'week', 'you', 'know', 'stats', 'grow'],
#  ['how',
#   'west',
#   'burned',
#   'thousands',
#   'wildfires',
#   'ablaze',
#   'california',
#   'alone'],
#  ['building', 'perfect', 'tracklist', 'life', 'leave', 'streets', 'ablaze'],
#  ['check', 'nsfw'],
#  ['first',
#   'night',
#   'retainers',
#   'its',
#   'quite',
#   'weird',
#   'better',
#   'get',
#   'used',
#   'i',
#   'wear',
#   'every',
#   'single',
#   'night',
#   'next',
#   'year',
#   'least'],
#  ['deputies', 'man', 'shot', 'brighton', 'home', 'set', 'ablaze'],
#  ['man', 'wife', 'get', 'six', 'years', 'jail', 'setting', 'ablaze', 'niece'],
#  ['santa',
#   'cruz',
#   'head',
#   'st',
#   'elizabeth',
#   'police',
#   'superintendent',
#   'lanford',
#   'salmon',
#   'r'],
#  ['police',
#   'arsonist',
#   'deliberately',
#   'set',
#   'black',
#   'church',
#   'in',
#   'north',
#   'carolinaåêablaze'],
#  ['noches',
#   'elbestia',
#   'alexissanchez',
#   'happy',
#   'see',
#   'teammates',
#   'training',
#   'hard',
#   'goodnight',
#   'gunners'],
#  ['kurds',
#   'trampling',
#   'turkmen',
#   'flag',
#   'later',
#   'set',
#   'ablaze',
#   'others',
#   'vandalized',
#   'offices',
#   'turkmen',
#   'front',
#   'diyala'],
#  ['truck',
#   'ablaze',
#   'voortrekker',
#   'ave',
#   'outside',
#   'or',
#   'tambo',
#   'intl',
#   'cargo',
#   'section'],
#  ['set',
#   'hearts',
#   'ablaze',
#   'every',
#   'city',
#   'gift',
#   'and',
#   'every',
#   'skyline',
#   'like',
#   'kiss',
#   'upon',
#   'lips'],
#  ['they',
#   'sky',
#   'ablaze',
#   'tonight',
#   'los',
#   'angeles',
#   'im',
#   'expecting',
#   'ig',
#   'fb',
#   'filled',
#   'sunset',
#   'shots',
#   'i',
#   'know',
#   'peeps'],
#  ['how',
#   'west',
#   'burned',
#   'thousands',
#   'wildfires',
#   'ablaze',
#   'california',
#   'alone',
#   'climate',
#   'energy'],
#  ['revel',
#   'wmv',
#   'videos',
#   'means',
#   'mac',
#   'farewell',
#   'ablaze',
#   'wmv',
#   'en',
#   'route',
#   'dvd',
#   'gtxrwm'],
#  ['progressive',
#   'greetings',
#   'in',
#   'month',
#   'students',
#   'would',
#   'set',
#   'pens',
#   'ablaze',
#   'the',
#   'torch',
#   'publications'],
#  ['rene',
#   'ablaze',
#   'amp',
#   'jacinta',
#   'secret',
#   'fallen',
#   'skies',
#   'edit',
#   'mar'],
#  ['steve',
#   'fires',
#   'something',
#   'else',
#   'california',
#   'tinderbox',
#   'clown',
#   'setting',
#   'hood',
#   'ablaze'],
#  ['nowplaying', 'rene', 'ablaze', 'amp', 'ian', 'buff', 'magnitude', 'edm'],
#  ['nxwestmidlands', 'huge', 'fire', 'wholesale', 'markets', 'ablaze'],
#  ['ablaze',
#   'time',
#   'talk',
#   'go',
#   'i',
#   'dont',
#   'know',
#   'i',
#   'make',
#   'due',
#   'work'],
#  ['i',
#   'cant',
#   'kids',
#   'cuz',
#   'i',
#   'got',
#   'bicycle',
#   'accident',
#   'amp',
#   'split',
#   'testicles',
#   'impossible',
#   'kids',
#   'michael',
#   'you',
#   'are',
#   'the',
#   'father'],
#  ['accident', 'w', 'nashvilletraffic', 'traffic', 'moving', 'slower', 'usual'],
#  ['accident',
#   'center',
#   'lane',
#   'blocked',
#   'santaclara',
#   'nb',
#   'great',
#   'america',
#   'pkwy',
#   'bayarea',
#   'traffic'],
#  ['had',
#   'personalinjury',
#   'accident',
#   'summer',
#   'read',
#   'advice',
#   'amp',
#   'see',
#   'solicitor',
#   'help',
#   'otleyhour'],
#  ['stlouis',
#   'caraccidentlawyer',
#   'speeding',
#   'among',
#   'top',
#   'causes',
#   'teen',
#   'accidents',
#   'car',
#   'accident'],
#  ['reported',
#   'motor',
#   'vehicle',
#   'accident',
#   'curry',
#   'herman',
#   'rd',
#   'near',
#   'stephenson',
#   'involving',
#   'overturned',
#   'vehicle',
#   'please',
#   'use'],
#  ['bigrigradio', 'live', 'accident', 'awareness'],
#  ['mile',
#   'marker',
#   'south',
#   'mooresville',
#   'iredell',
#   'vehicle',
#   'accident',
#   'ramp',
#   'closed',
#   'pm'],
#  ['rt',
#   'sleepjunkies',
#   'sleeping',
#   'pills',
#   'double',
#   'risk',
#   'car',
#   'accident'],
#  ['by', 'accident', 'knew', 'gon', 'happen'],
#  ['traffic', 'accident', 'n', 'cabrillo', 'hwymagellan', 'av', 'mir'],
#  ['mile',
#   'marker',
#   'south',
#   'mooresville',
#   'iredell',
#   'vehicle',
#   'accident',
#   'congestion',
#   'pm'],
#  ['pastor', 'scene', 'accidentwho', 'owner', 'range', 'rover'],
#  ['mom',
#   'didnt',
#   'get',
#   'home',
#   'fast',
#   'wished',
#   'mom',
#   'accident',
#   'truck',
#   'spilt',
#   'mayonnaise'],
#  ['i',
#   'horrible',
#   'car',
#   'accident',
#   'past',
#   'sunday',
#   'im',
#   'finally',
#   'able',
#   'get',
#   'around',
#   'thank',
#   'god'],
#  ['can',
#   'wait',
#   'see',
#   'pissed',
#   'donnie',
#   'i',
#   'tell',
#   'i',
#   'another',
#   'accident'],
#  ['truckcrash',
#   'overturns',
#   'on',
#   'fortworth',
#   'interstate',
#   'click',
#   'youve',
#   'crashgt'],
#  ['accident', 'ashville', 'us', 'sb', 'sr', 'traffic'],
#  ['carolina',
#   'accident',
#   'motorcyclist',
#   'dies',
#   'crash',
#   'with',
#   'car',
#   'that',
#   'crossed',
#   'median',
#   'a',
#   'motorcycle',
#   'rider',
#   'traveling'],
#  ['fyi', 'cadfyi', 'accident', 'property', 'piner', 'rdhorndale', 'dr'],
#  ['rt',
#   'naayf',
#   'first',
#   'accident',
#   'years',
#   'turning',
#   'onto',
#   'chandanee',
#   'magu',
#   'near',
#   'mma',
#   'taxi',
#   'rammed',
#   'i',
#   'halfway',
#   'turned',
#   'everyone'],
#  ['accident',
#   'left',
#   'lane',
#   'blocked',
#   'manchester',
#   'rt',
#   'nb',
#   'eddy',
#   'rd',
#   'stop',
#   'go',
#   'traffic',
#   'back',
#   'delay',
#   'mins',
#   'traffic'],
#  ['accident', 'property', 'damage', 'piner', 'rdhorndale', 'dr'],
#  ['accident'],
#  ['fyi', 'cadfyi', 'accident', 'property', 's', 'st'],
#  ['pm', 'traffic', 'accident', 'no', 'injury', 'willis', 'foreman', 'rd'],
#  ['aashiqui',
#   'actress',
#   'anu',
#   'aggarwal',
#   'on',
#   'her',
#   'nearfatal',
#   'accident'],
#  ['suffield', 'alberta', 'accident'],
#  ['mile',
#   'backup',
#   'southaccident',
#   'blocking',
#   'right',
#   'lanes',
#   'exit',
#   'langtree',
#   'rdconsider',
#   'nc',
#   'nc',
#   'nc',
#   'alternate'],
#  ['has',
#   'accident',
#   'changed',
#   'life',
#   'we',
#   'help',
#   'determine',
#   'options',
#   'financially',
#   'support',
#   'life',
#   'care',
#   'plans',
#   'ongoing',
#   'treatment'],
#  ['breaking',
#   'deadly',
#   'motorcycle',
#   'car',
#   'accident',
#   'happened',
#   'hagerstown',
#   'today',
#   'ill',
#   'details',
#   'whag'],
#  ['flowri', 'marinading', 'accident'],
#  ['car',
#   'even',
#   'week',
#   'got',
#   'fucking',
#   'car',
#   'accident',
#   'mfs',
#   'cant',
#   'fucking',
#   'drive'],
#  ['norwaymfa',
#   'bahrain',
#   'police',
#   'previously',
#   'died',
#   'road',
#   'accident',
#   'killed',
#   'explosion'],
#  ['i',
#   'still',
#   'heard',
#   'church',
#   'leaders',
#   'kenya',
#   'coming',
#   'forward',
#   'comment',
#   'accident',
#   'issue',
#   'disciplinary',
#   'measuresarrestpastornganga'],
#  ['aftershockdelo', 'scuf', 'ps', 'live', 'game', 'cya'],
#  ['the',
#   'man',
#   'drive',
#   'effort',
#   'gets',
#   'painful',
#   'man',
#   'win',
#   'roger',
#   'bannister'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['there',
#   'victory',
#   'bargain',
#   'basement',
#   'prices',
#   'dwight',
#   'david',
#   'eisenhower'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['nobody', 'remembers', 'came', 'second', 'charles', 'schulz'],
#  ['aftershockdelo',
#   'im',
#   'speaking',
#   'someone',
#   'using',
#   'scuf',
#   'people',
#   'end',
#   'getting',
#   'ps',
#   'also'],
#  ['the', 'harder', 'conflict', 'glorious', 'triumph', 'thomas', 'paine'],
#  ['growingupspoiled',
#   'going',
#   'clay',
#   'pigeon',
#   'shooting',
#   'crying',
#   'aftershock'],
#  ['so', 'guess', 'one', 'actually', 'wants', 'free', 'aftershock', 'tc'],
#  ['aftershock',
#   'terrifying',
#   'best',
#   'roller',
#   'coaster',
#   'ive',
#   'ever',
#   'disclaimer',
#   'ive'],
#  ['aftershock'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['kjfordays', 'im', 'seeing', 'issues', 'aftershock'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['wisdomwed',
#   'bonus',
#   'minute',
#   'daily',
#   'habits',
#   'could',
#   'really',
#   'improve',
#   'life',
#   'how',
#   'many',
#   'already',
#   'lifehacks'],
#  ['aftershock',
#   'protect',
#   'yourself',
#   'profit',
#   'next',
#   'global',
#   'financial',
#   'meltdown',
#   'david',
#   'wiedemer',
#   'http'],
#  ['that',
#   'moment',
#   'get',
#   'scary',
#   'roller',
#   'coaster',
#   'guy',
#   'behind',
#   'screaming',
#   'bloody',
#   'murder',
#   'silverwood',
#   'aftershock'],
#  ['aftershock', 'streaming', 'youtube'],
#  ['gtgt',
#   'aftershock',
#   'protect',
#   'yourself',
#   'profit',
#   'next',
#   'global',
#   'financial',
#   'book',
#   'esquireattire'],
#  ['sometimes',
#   'face',
#   'difficulties',
#   'youre',
#   'something',
#   'wrong',
#   'youre',
#   'something',
#   'right',
#   'joel',
#   'osteen'],
#  ['the',
#   'thing',
#   'stands',
#   'dream',
#   'try',
#   'belief',
#   'actually',
#   'possible',
#   'joel',
#   'brown'],
#  ['praise', 'god', 'ministry', 'tells', 'like', 'wdyouth', 'biblestudy'],
#  ['remembering',
#   'going',
#   'die',
#   'best',
#   'way',
#   'i',
#   'know',
#   'avoid',
#   'trap',
#   'thinking',
#   'something',
#   'lose',
#   'steve',
#   'jobs'],
#  ['tried', 'orange', 'aftershock', 'today', 'my', 'life', 'never'],
#  ['onfireanders', 'i', 'love', 'bb'],
#  ['aftershock'],
#  ['aftershock',
#   'back',
#   'school',
#   'kick',
#   'great',
#   'i',
#   'want',
#   'thank',
#   'everyone',
#   'making',
#   'possible',
#   'what',
#   'great',
#   'night'],
#  ['people', 'say', 'done', 'interrupt', 'george', 'bernard', 'shaw'],
#  ['the',
#   'first',
#   'man',
#   'gets',
#   'oyster',
#   'second',
#   'man',
#   'gets',
#   'shell',
#   'andrew',
#   'carnegie'],
#  ['anyone',
#   'need',
#   'pu',
#   'tonight',
#   'i',
#   'play',
#   'hybrid',
#   'slayer',
#   'eu',
#   'hmu',
#   'empirikgaming',
#   'codawscrims',
#   'aftershockorg'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'news'],
#  ['strict',
#   'liability',
#   'context',
#   'airplane',
#   'accident',
#   'pilot',
#   'error',
#   'common',
#   'component',
#   'aviation',
#   'cr'],
#  ['crobscarla', 'lifetime', 'odds', 'dying', 'airplane', 'accident'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wedn'],
#  ['alexalltimelow',
#   'awwww',
#   'theyre',
#   'airplane',
#   'accident',
#   'theyre',
#   'gon',
#   'na',
#   'die',
#   'cuties',
#   'good',
#   'job'],
#  ['family',
#   'members',
#   'osama',
#   'bin',
#   'laden',
#   'died',
#   'airplane',
#   'accident',
#   'ironic',
#   'mhmmm',
#   'gov',
#   'shit',
#   'suspect'],
#  ['man', 'goes', 'airplane', 'engine', 'accident', 'via', 'youtube'],
#  ['horrible', 'accident', 'man', 'died', 'in', 'wings', 'airplane'],
#  ['a',
#   'cessna',
#   'airplane',
#   'accident',
#   'ocampo',
#   'coahuila',
#   'mexico',
#   'july',
#   'killed',
#   'four',
#   'men',
#   'including',
#   'state',
#   'coahuila',
#   'government',
#   'official'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'in',
#   'wings',
#   'airplane',
#   'watchthevideo'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday',
#   'began',
#   'examining'],
#  ['kca',
#   'mbataweel',
#   'rip',
#   'binladen',
#   'family',
#   'members',
#   'killed',
#   'airplanes',
#   'accident'],
#  ['i',
#   'almost',
#   'sent',
#   'coworker',
#   'nudes',
#   'accident',
#   'thank',
#   'god',
#   'airplane',
#   'mode'],
#  ['mickinyman',
#   'theatlantic',
#   'that',
#   'might',
#   'killed',
#   'airplane',
#   'accident',
#   'night',
#   'car',
#   'wreck',
#   'politics',
#   'best'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'mlb'],
#  ['this',
#   'unbelievably',
#   'insane',
#   'man',
#   'airport',
#   'airplane',
#   'aircraft',
#   'aeroplane',
#   'runway',
#   'accident'],
#  ['horrible', 'accident', 'man', 'died', 'in', 'wings'],
#  ['horrible', 'accident', 'man', 'died', 'in', 'wings', 'airplane'],
#  ['usama',
#   'bin',
#   'ladins',
#   'family',
#   'dead',
#   'airplane',
#   'crash',
#   'naturally',
#   'accident'],
#  ['pilot',
#   'dies',
#   'in',
#   'plane',
#   'crash',
#   'at',
#   'car',
#   'festival',
#   'via',
#   'youtube',
#   'crash',
#   'aircraft',
#   'airplane',
#   'pilot',
#   'death',
#   'accident',
#   'carfest'],
#  ['strict', 'liability', 'context', 'airplane', 'accident'],
#  ['dtn',
#   'brazil',
#   'experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'exp'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wedn'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'in',
#   'wings',
#   'of',
#   'wtf',
#   'you',
#   'believe',
#   'your',
#   'eyes'],
#  ['nicole',
#   'fletcher',
#   'one',
#   'victim',
#   'crashed',
#   'airplane',
#   'times',
#   'ago',
#   'the',
#   'accident',
#   'left',
#   'little',
#   'bit',
#   'trauma',
#   'although',
#   'shes'],
#  ['omg', 'horrible', 'accident', 'man', 'died', 'wings', 'airplane'],
#  ['omg',
#   'i',
#   'dont',
#   'believe',
#   'rip',
#   'bro',
#   'airplane',
#   'accident',
#   'jetengine',
#   'turbojet',
#   'boing'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday',
#   'began',
#   'examining'],
#  ['i', 'airplane', 'accident'],
#  ['my',
#   'phone',
#   'looks',
#   'like',
#   'car',
#   'ship',
#   'airplane',
#   'accident',
#   'terrible'],
#  ['statistically',
#   'im',
#   'risk',
#   'getting',
#   'killed',
#   'cop',
#   'i',
#   'dying',
#   'airplane',
#   'accident'],
#  ['airplane', 'crashes', 'house', 'colombia', 'people', 'die', 'accident'],
#  ['the', 'shooting', 'airplane', 'accident'],
#  ['could',
#   'drone',
#   'cause',
#   'airplane',
#   'accident',
#   'pilots',
#   'worried',
#   'use',
#   'drones',
#   'esp',
#   'close',
#   'vicinity',
#   'airports'],
#  ['early',
#   'wake',
#   'call',
#   'sister',
#   'begging',
#   'come',
#   'amp',
#   'ride',
#   'wher',
#   'ambulance',
#   'hospital',
#   'rodkiai'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['two',
#   'air',
#   'ambulances',
#   'scene',
#   'serious',
#   'crash',
#   'two',
#   'cars',
#   'lorry'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'reuters',
#   'yugvani'],
#  ['leading',
#   'emergency',
#   'services',
#   'boss',
#   'welcomes',
#   'new',
#   'ambulance',
#   'charity'],
#  ['anyone',
#   'travelling',
#   'aberystwythshrewsbury',
#   'right',
#   'theres',
#   'incident',
#   'services',
#   'halt',
#   'outside',
#   'shrews',
#   'ambulance',
#   'scene'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'of',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['new',
#   'nanotech',
#   'device',
#   'will',
#   'be',
#   'able',
#   'to',
#   'target',
#   'and',
#   'destroy',
#   'blood',
#   'clots'],
#  ['hella', 'crazy', 'fights', 'ambulance', 'couple', 'mosh', 'pits'],
#  ['if',
#   'i',
#   'get',
#   'run',
#   'ambulance',
#   'i',
#   'lucky',
#   'justsaying',
#   'randomthought'],
#  ['news',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'tilnow',
#   'dna'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['tanslash', 'waiting', 'ambulance'],
#  ['fouseytube', 'ok', 'need', 'ambulance', 'hahahah', 'good'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'of',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['pakistan', 'air', 'ambulance', 'helicopter', 'crash', 'kills', 'nine'],
#  ['thenissonian',
#   'rejectdcartoons',
#   'nissan',
#   'ok',
#   'need',
#   'medical',
#   'assistance',
#   'call',
#   'ambulance',
#   'need'],
#  ['ny', 'emts', 'petition', 'per', 'hour', 'ems', 'paramedics', 'ambulance'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'of',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'of',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['kiwikaryn',
#   'check',
#   'whats',
#   'parking',
#   'lot',
#   'he',
#   'said',
#   'last',
#   'year',
#   'ambulance',
#   'st',
#   'johns'],
#  ['dont', 'know', 'way', 'ambulance', 'coming', 'ltlt'],
#  ['reuters',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['why', 'ambulance', 'right', 'outside', 'work'],
#  ['this', 'dog', 'thinks', 'hes', 'ambulance'],
#  ['happening',
#   'now',
#   'hatzolah',
#   'ems',
#   'ambulance',
#   'responding',
#   'with',
#   'dual',
#   'sirens'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'worldnews'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'worldnews'],
#  ['whats', 'police', 'ambulance', 'number', 'lesotho', 'any', 'body', 'know'],
#  ['aaceorg',
#   'i',
#   'surprised',
#   'still',
#   'standardised',
#   'clinical',
#   'practice',
#   'across',
#   'nhs',
#   'ambulance',
#   'trust'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['people', 'try', 'jwalk', 'ambulance', 'passing', 'i', 'hate'],
#  ['the',
#   'episode',
#   'trunks',
#   'annihilated',
#   'freiza',
#   'cleanest',
#   'shit',
#   'ever',
#   'he',
#   'showed',
#   'nigga',
#   'mercy'],
#  ['they',
#   'shall',
#   'be',
#   'annihilated',
#   'and',
#   'all',
#   'of',
#   'their',
#   'petebests',
#   'dessicated',
#   'and',
#   'laid',
#   'bare',
#   'then',
#   'you',
#   'shall',
#   'kneel',
#   'before',
#   'me'],
#  ['uribe', 'annihilated', 'baseball', 'mets'],
#  ['marksmaponyane',
#   'heysundowns',
#   'annihilated',
#   'previous',
#   'meeting',
#   'celticindeed',
#   'improvement'],
#  ['tneazzy',
#   'mizzou',
#   'annihilated',
#   'florida',
#   'past',
#   'seasons',
#   'even',
#   'ended',
#   'muschamps',
#   'career',
#   'cant',
#   'compete',
#   'bama'],
#  ['annihilated', 'abs'],
#  ['be',
#   'annihilated',
#   'status',
#   'education',
#   'mba',
#   'behalf',
#   'easy',
#   'street',
#   'careen',
#   'eovm'],
#  ['luka',
#   'they',
#   'die',
#   'all',
#   'everything',
#   'annihilated',
#   'alois',
#   'trancy'],
#  ['acarewornheart',
#   'have',
#   'good',
#   'un',
#   'fella',
#   'sorry',
#   'i',
#   'wont',
#   'get',
#   'annihilated'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'via',
#   'viralspell'],
#  ['you', 'must', 'annihilated'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'via',
#   'viralspell'],
#  ['boom', 'your', 'country', 'entirely', 'annihilated', 'britain'],
#  ['amirkingkhan',
#   'would',
#   'annihilated',
#   'might',
#   'well',
#   'thank',
#   'floydmayweather'],
#  ['one',
#   'thing',
#   'suregod',
#   'promised',
#   'israel',
#   'annihilated',
#   'butthe',
#   'horror',
#   'iran',
#   'wnukes'],
#  ['violentfeminazi',
#   'i',
#   'guess',
#   'thats',
#   'ok',
#   'armenians',
#   'since',
#   'weve',
#   'spent',
#   'history',
#   'getting',
#   'annihilated'],
#  ['years',
#   'since',
#   'annihilated',
#   'people',
#   'instantly',
#   'became',
#   'aware',
#   'ability',
#   'annihilate',
#   'whole',
#   'humanity'],
#  ['day',
#   'tryouts',
#   'went',
#   'good',
#   'minus',
#   'fact',
#   'i',
#   'stopped',
#   'quickly',
#   'get',
#   'short',
#   'ball',
#   'annihilated',
#   'toenail',
#   'injury',
#   'even'],
#  ['during',
#   'oryx',
#   'symbol',
#   'arabian',
#   'peninsula',
#   'annihilated',
#   'hunters'],
#  ['to',
#   'luka',
#   'they',
#   'die',
#   'all',
#   'everything',
#   'annihilated',
#   'alois',
#   'trancy'],
#  ['ready', 'get', 'annihilated', 'bucs', 'game'],
#  ['philipduncan',
#   'breakfastone',
#   'people',
#   'annihilated',
#   'last',
#   'nights',
#   'weather',
#   'really',
#   'philip',
#   'thought',
#   'would',
#   'forecast'],
#  ['domain',
#   'sophistication',
#   'annihilated',
#   'closely',
#   'uptotheminute',
#   'feat',
#   'zrnf'],
#  ['stormbeard',
#   'steellord',
#   'i',
#   'seen',
#   'judas',
#   'priest',
#   'rob',
#   'came',
#   'back',
#   'scorpions',
#   'support',
#   'fucking',
#   'annihilated',
#   'place',
#   'astonishing',
#   'gig'],
#  ['officially',
#   'skipping',
#   'hashtag',
#   'its',
#   'getting',
#   'annihilated',
#   'reviews',
#   'bummer'],
#  ['tomcatarts',
#   'thus',
#   'explaining',
#   'annihilated',
#   'but',
#   'case',
#   'survivor',
#   'evolved',
#   'became',
#   'godlike'],
#  ['completely', 'annihilated', 'cech', 'paul', 'keegan', 'time', 'alive'],
#  ['tomcatarts',
#   'annihilated',
#   'legion',
#   'the',
#   'survivors',
#   'imperfect',
#   'hybrid',
#   'project',
#   'quickly',
#   'formed',
#   'new',
#   'secret',
#   'cell'],
#  ['sirbrandonknt',
#   'exactly',
#   'thats',
#   'lesnarcena',
#   'match',
#   'summerslam',
#   'last',
#   'year',
#   'great',
#   'brock',
#   'annihilated',
#   'guy',
#   'whos'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'via',
#   'viralspell'],
#  ['annihilated',
#   'in',
#   'damascus',
#   'syrian',
#   'army',
#   'grinds',
#   'and',
#   'his',
#   'gang',
#   'into',
#   'the',
#   'manure',
#   'pile'],
#  ['thatdes',
#   'ok',
#   'wasnt',
#   'completely',
#   'forthright',
#   'may',
#   'also',
#   'food',
#   'coma',
#   'bc',
#   'kebabtahinipickles',
#   'also',
#   'annihilated',
#   'wfries'],
#  ['a',
#   'fun',
#   'filled',
#   'happyhour',
#   'simmons',
#   'bar',
#   'camden',
#   'handsome',
#   'one',
#   'i',
#   'got',
#   'annihilated',
#   'apart',
#   'game'],
#  ['juanny', 'beisbol', 'sr', 'annihilated', 'ball', 'lgm'],
#  ['rvfriedmann',
#   'hell',
#   'fraction',
#   'belief',
#   'total',
#   'annihilation',
#   'destruction',
#   'usa',
#   'lodisilverado',
#   'ritzyjewels'],
#  ['potus',
#   'maybe',
#   'call',
#   'israel',
#   'tell',
#   'sorry',
#   'pres',
#   'sold',
#   'river',
#   'annihilation'],
#  ['evildead', 'annihilation', 'civilization'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['annihilating', 'quarterstaff', 'annihilation'],
#  ['world',
#   'annihilation',
#   'vs',
#   'self',
#   'transformation',
#   'aliens',
#   'attack',
#   'exterminate',
#   'humans'],
#  ['starmade', 'stardate', 'planetary', 'annihilation', 'via', 'youtube'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['kimkardashian',
#   'please',
#   'sign',
#   'share',
#   'petition',
#   'save',
#   'wild',
#   'horses',
#   'arizona'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['theellenshow',
#   'please',
#   'check',
#   'salt',
#   'river',
#   'horses',
#   'help',
#   'stop',
#   'annihilation',
#   'happen',
#   'without',
#   'signatureschange',
#   'org',
#   'thx'],
#  ['are', 'souls', 'punished', 'withåêannihilation'],
#  ['calfreedommom',
#   'mention',
#   'major',
#   'contributor',
#   'annihilation',
#   'israel'],
#  ['willienelson',
#   'we',
#   'need',
#   'help',
#   'horses',
#   'dieplease',
#   'rt',
#   'amp',
#   'sign',
#   'petitiontake',
#   'stand',
#   'amp',
#   'voice'],
#  ['i',
#   'reject',
#   'laws',
#   'misguided',
#   'false',
#   'prophets',
#   'imprison',
#   'nations',
#   'fueling',
#   'self',
#   'annihilation'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['the',
#   'annihilation',
#   'jeb',
#   'christie',
#   'amp',
#   'kasich',
#   'less',
#   'hours',
#   'away',
#   'please',
#   'god',
#   'allow',
#   'least',
#   'one',
#   'full',
#   'day'],
#  ['barbitwins',
#   'we',
#   'need',
#   'helphorses',
#   'die',
#   'please',
#   'rt',
#   'amp',
#   'sign',
#   'petition',
#   'take',
#   'stand',
#   'amp',
#   'voice'],
#  ['whippenz',
#   'we',
#   'need',
#   'help',
#   'horses',
#   'dieplease',
#   'rt',
#   'amp',
#   'sign',
#   'petitiontake',
#   'stand',
#   'amp',
#   'voice'],
#  ['hey',
#   'az',
#   'sign',
#   'petition',
#   'save',
#   'wildhorses',
#   'tantonationalforest',
#   'a',
#   'rollingstones',
#   'singalong',
#   'order'],
#  ['stop', 'annihilation', 'salt', 'river', 'wild', 'horses', 'via', 'change'],
#  ['sonofbaldwin',
#   'hes',
#   'current',
#   'nova',
#   'bookslast',
#   'i',
#   'checkedhe',
#   'tied',
#   'books',
#   'rider',
#   'died',
#   'annihilation'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['please', 'sign', 'amp', 'rt', 'save', 'saltriverwildhorses'],
#  ['thanks',
#   'count',
#   'dante',
#   'do',
#   'join',
#   'us',
#   'by',
#   'following',
#   'the',
#   'annihilation',
#   'zone',
#   'johnny'],
#  ['world',
#   'annihilation',
#   'vs',
#   'self',
#   'transformation',
#   'aliens',
#   'attack',
#   'exterminate',
#   'humans'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['im', 'gon', 'na', 'fight', 'taylor', 'soon', 'i', 'get'],
#  ['ohh',
#   'no',
#   'fukurodani',
#   'didnt',
#   'survive',
#   'the',
#   'apocalypse',
#   'bokuto',
#   'feels',
#   'horrible',
#   'poor',
#   'boy',
#   'ppor',
#   'child'],
#  ['another', 'jocelyn', 'birthday', 'apocalypse'],
#  ['rt',
#   'rt',
#   'stephenscifi',
#   'adaptation',
#   'watch',
#   'charlie',
#   'humans',
#   'apocalypse',
#   'now',
#   'now',
#   'optioned',
#   'film',
#   'sciencefiction'],
#  ['apocalypse', 'please'],
#  ['another',
#   'hour',
#   'its',
#   'august',
#   'heres',
#   'red',
#   'rover',
#   'zombie',
#   'apocalypse',
#   'internetradio'],
#  ['honeybunzgem',
#   'primalkitchen',
#   'i',
#   'feel',
#   'like',
#   'pullup',
#   'one',
#   'stages',
#   'apocalypse'],
#  ['shes',
#   'kinda',
#   'hot',
#   'played',
#   'radio',
#   'today',
#   'whats',
#   'next',
#   'disease',
#   'the',
#   'apocalypse',
#   'started',
#   'everyone',
#   'be',
#   'careful'],
#  ['but', 'apocalypse', 'lol', 'gf'],
#  ['i',
#   'know',
#   'question',
#   'interpretation',
#   'sign',
#   'apocalypse',
#   'i',
#   'called'],
#  ['julie', 'r', 'apocalypse', 'version', 'romeo', 'juliet', 'warmbodies'],
#  ['apocalypse', 'upon', 'us'],
#  ['rt',
#   'fittscott',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'amp',
#   'more',
#   'mod',
#   'showcase',
#   'popularmmos'],
#  ['and', 'begins', 'day', 'one', 'snow', 'apocalypse'],
#  ['rt',
#   'ourmothermary',
#   'short',
#   'reading',
#   'apocalypse',
#   'in',
#   'spirit',
#   'angel',
#   'took',
#   'top',
#   'enormous',
#   'high',
#   'mountain'],
#  ['candylit',
#   'imagine',
#   'sarumi',
#   'zombie',
#   'apocalypse',
#   'fighting',
#   'back',
#   'back',
#   'heart',
#   'heart',
#   'conversations'],
#  ['rt',
#   'i',
#   'liked',
#   'youtube',
#   'video',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'amp',
#   'more'],
#  ['and', 'thats', 'planet', 'lone', 'audience', 'apocalypse'],
#  ['dad',
#   'bought',
#   'dvd',
#   'looks',
#   'like',
#   'science',
#   'doc',
#   'front',
#   'i',
#   'read',
#   'back',
#   'actually',
#   'impending',
#   'biblical',
#   'apocalypse'],
#  ['alexandrapullin',
#   'it',
#   'indeed',
#   'if',
#   'apocalypse',
#   'comes',
#   'week',
#   'i',
#   'know',
#   'ill'],
#  ['go',
#   'look',
#   'at',
#   'grizzly',
#   'peak',
#   'right',
#   'now',
#   'it',
#   'looks',
#   'like',
#   'beginning',
#   'dystopian',
#   'apocalypse',
#   'movie'],
#  ['my', 'niece', 'asked', 'would', 'scared', 'apocalypse'],
#  ['theres',
#   'storm',
#   'cairo',
#   'latest',
#   'xmen',
#   'apocalypse',
#   'set',
#   'photo',
#   'via',
#   'yahootv'],
#  ['minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'amp',
#   'more',
#   'mod',
#   'showcase',
#   'popularmmos',
#   'via',
#   'youtube'],
#  ['shot',
#   'through',
#   'the',
#   'heart',
#   'xv',
#   'you',
#   'going',
#   'totally',
#   'give',
#   'love',
#   'bad',
#   'name',
#   'heart',
#   'pierc'],
#  ['rt',
#   'geekapocalypse',
#   'gmt',
#   'hesse',
#   'plays',
#   'dark',
#   'souls',
#   'day',
#   'etcpb'],
#  ['i', 'know', 'go', 'zombies', 'take'],
#  ['the',
#   'latest',
#   'bryansinger',
#   'reveals',
#   'storm',
#   'queen',
#   'apocalypse',
#   'rupaul',
#   'alexshipppp'],
#  ['shadow', 'boxing', 'apocalypse'],
#  ['short',
#   'reading',
#   'apocalypse',
#   'in',
#   'spirit',
#   'angel',
#   'took',
#   'top',
#   'enormous',
#   'high',
#   'mountain'],
#  ['enjoyed',
#   'liveaction',
#   'attack',
#   'titan',
#   'every',
#   'time',
#   'i',
#   'see',
#   'posters',
#   'im',
#   'reminded',
#   'freshly',
#   'clean',
#   'coiffed',
#   'everyone',
#   'apocalypse'],
#  ['i',
#   'liked',
#   'youtube',
#   'video',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'amp',
#   'more',
#   'mod',
#   'showcase'],
#  ['pbban',
#   'avysss',
#   'armageddon',
#   'do',
#   'not',
#   'kill',
#   'flags',
#   'only',
#   'fast',
#   'xp',
#   'reason'],
#  ['pbban',
#   'armageddon',
#   'do',
#   'not',
#   'kill',
#   'flags',
#   'only',
#   'fast',
#   'xp',
#   'reason'],
#  ['official',
#   'vid',
#   'doublecups',
#   'gtgt',
#   'gtgt',
#   'trubgme',
#   'prod',
#   'thisizbwright',
#   'gtgt',
#   'armageddon'],
#  ['ouvindo', 'peace', 'love', 'amp', 'armageddon'],
#  ['best', 'movie', 'youve', 'ever', 'seen', 'armageddon'],
#  ['bed',
#   'time',
#   'dont',
#   'wake',
#   'unless',
#   'revolution',
#   'armageddon',
#   'start'],
#  ['red', 'faction', 'armageddon', 'microsoft', 'xbox', 'full', 'read', 'ebay'],
#  ['katiekatcubs',
#   'already',
#   'know',
#   'shit',
#   'goes',
#   'world',
#   'series',
#   'armageddon'],
#  ['rt',
#   'love',
#   'truelove',
#   'romance',
#   'lith',
#   'voodoo',
#   'seduction',
#   'astrology',
#   'rtrrt',
#   'lotz',
#   'apocalypse',
#   'armageddon'],
#  ['im',
#   'gon',
#   'na',
#   'beat',
#   'armageddon',
#   'hsu',
#   'hao',
#   'got',
#   'flawless',
#   'first',
#   'try'],
#  ['enews',
#   'ben',
#   'afflecki',
#   'know',
#   'theres',
#   'wifekids',
#   'girls',
#   'i',
#   'cant',
#   'help',
#   'ive',
#   'loved',
#   'since',
#   'armageddon',
#   'eonlinechat'],
#  ['if',
#   'id',
#   'long',
#   'coat',
#   'hand',
#   'id',
#   'worn',
#   'the',
#   'certainty',
#   'armageddon',
#   'bears',
#   'sense',
#   'occasion'],
#  ['your',
#   'phone',
#   'is',
#   'spying',
#   'on',
#   'you',
#   'hidden',
#   'back',
#   'door',
#   'nsa',
#   'data',
#   'mining',
#   'software',
#   'the',
#   'financial',
#   'armageddon',
#   'blog'],
#  ['pbban',
#   'armageddon',
#   'do',
#   'not',
#   'kill',
#   'flags',
#   'only',
#   'fast',
#   'xp',
#   'reason'],
#  ['rt',
#   'rtrrtcoach',
#   'love',
#   'truelove',
#   'romance',
#   'lith',
#   'voodoo',
#   'seduction',
#   'astrology',
#   'rtrrt',
#   'lotz',
#   'apocalypse',
#   'armageddon'],
#  ['pbban',
#   'fighterdena',
#   'armageddon',
#   'do',
#   'not',
#   'kill',
#   'flags',
#   'only',
#   'fast',
#   'xp',
#   'reason'],
#  ['photo',
#   'sketch',
#   'i',
#   'based',
#   'a',
#   'taste',
#   'armageddon',
#   'episode',
#   'startrek',
#   'tos'],
#  ['armageddon'],
#  ['aberdeenfc',
#   'aberdeenfanpage',
#   'good',
#   'luck',
#   'tomorrow',
#   'night',
#   'get',
#   'coefficient',
#   'points',
#   'plz',
#   'armageddon'],
#  ['armageddon'],
#  ['rohnertparkdps',
#   'youre',
#   'another',
#   'one',
#   'history',
#   'books',
#   'thank',
#   'justice',
#   'department',
#   'and',
#   'way',
#   'i',
#   'havent',
#   'paid',
#   'income',
#   'tax'],
#  ['vladimir',
#   'putin',
#   'issues',
#   'major',
#   'warning',
#   'but',
#   'is',
#   'it',
#   'too',
#   'late',
#   'to',
#   'escape',
#   'armageddon'],
#  ['gods',
#   'kingdom',
#   'heavenly',
#   'govt',
#   'rule',
#   'people',
#   'earth',
#   'armageddon'],
#  ['l',
#   'b',
#   'entertainment',
#   'lot',
#   'brucewillis',
#   'movies',
#   'dvd',
#   'die',
#   'hard',
#   'monkeys',
#   'armageddon',
#   'sixth',
#   'ebay',
#   'auction'],
#  ['talk', 'goof', 'guild', 'saunders', 'come', 'right', 'stage'],
#  ['karnythia',
#   'niece',
#   'gaining',
#   'ability',
#   'stand',
#   'im',
#   'getting',
#   'prepared',
#   'toddler',
#   'apocalypse',
#   'armageddon'],
#  ['check',
#   'preppers',
#   'doomsday',
#   'must',
#   'have',
#   'library',
#   'collection',
#   'on',
#   'cd',
#   'shtf',
#   'preppertalk',
#   'survival',
#   'prepper',
#   'via',
#   'ebay'],
#  ['erker',
#   'again',
#   'eep',
#   'thought',
#   'yesterday',
#   'i',
#   'saw',
#   'hella',
#   'scary',
#   'hail',
#   'armageddon'],
#  ['so',
#   'ahamedis',
#   'think',
#   'messiah',
#   'already',
#   'come',
#   'years',
#   'ago',
#   'where',
#   'armageddon',
#   'where',
#   'dajaal',
#   'where',
#   'gog',
#   'amp',
#   'magog'],
#  ['sadly', 'how', 'windows', 'reveals', 'microsofts', 'ethics', 'armageddon'],
#  ['armageddon', 'averted', 'el', 'patron', 'ultimalucha'],
#  ['samihonkonen',
#   'if',
#   'time',
#   'hours',
#   'latest',
#   'series',
#   'blueprint',
#   'armageddon',
#   'extremely',
#   'impressive'],
#  ['european', 'fitba', 'till', 'christmas', 'armageddon'],
#  ['christians',
#   'united',
#   'israel',
#   'cufi',
#   'jews',
#   'convert',
#   'soon',
#   'die',
#   'armageddon',
#   'us'],
#  ['official',
#   'vid',
#   'gt',
#   'doublecups',
#   'gtgt',
#   'gtgt',
#   'trubgme',
#   'prod',
#   'thisizbwright',
#   'gtgt',
#   'armageddon'],
#  ['tomorrow', 'day', 'start', 'armageddon', 'preseasonworkouts'],
#  ['lee', 'comedy', 'working', 'class', 'tories', 'prepare', 'armageddon'],
#  ['charts',
#   'prove',
#   'financial',
#   'crisis',
#   'part',
#   'has',
#   'begun',
#   'the',
#   'financial',
#   'armageddon',
#   'economic',
#   'collapse',
#   'blog',
#   'tracks',
#   'tren'],
#  ['paul',
#   'craig',
#   'roberts',
#   'vladimir',
#   'putin',
#   'issues',
#   'major',
#   'warning',
#   'but',
#   'is',
#   'it',
#   'too',
#   'late',
#   'to',
#   'escape',
#   'a',
#   'brics',
#   'roberts',
#   'russia'],
#  ['rohnertparkdps',
#   'youre',
#   'stage',
#   'right',
#   'lights',
#   'isnt',
#   'funny',
#   'where',
#   'get',
#   'goofballs',
#   'staff',
#   'pd'],
#  ['official',
#   'vid',
#   'thereal',
#   'gtgtgt',
#   'gtgtgt',
#   'trubgme',
#   'gtgtgt',
#   'armageddon',
#   'comin',
#   'soon'],
#  ['well',
#   'done',
#   'celtic',
#   'fingers',
#   'crossed',
#   'aberdeen',
#   'tomorrow',
#   'night',
#   'armageddon',
#   'eh'],
#  ['beyonce', 'is', 'pick', 'fan', 'army', 'beyhive'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['seconds', 'summer', 'is', 'pick', 'fan', 'army'],
#  ['is', 'pick', 'fan', 'army', 'beyhive'],
#  ['is', 'pick', 'fan', 'army', 'beyhive'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['seeing',
#   'army',
#   'whitewalkers',
#   'first',
#   'thing',
#   'slightly',
#   'intrigued',
#   'got',
#   'far'],
#  ['build',
#   'kingdom',
#   'lead',
#   'army',
#   'victory',
#   'start',
#   'g',
#   'friend',
#   'code',
#   'lzktjnox'],
#  ['salvation',
#   'army',
#   'hosts',
#   'rally',
#   'reconnect',
#   'fathers',
#   'children',
#   'the',
#   'salvation',
#   'army',
#   'hosting',
#   'back',
#   'school'],
#  ['vote',
#   'directioners',
#   'vs',
#   'queens',
#   'round',
#   'billboard',
#   'fanarmyfaceoff'],
#  ['but',
#   'build',
#   'army',
#   'dogs',
#   'leader',
#   'lion',
#   'dogs',
#   'fight',
#   'like',
#   'lion'],
#  ['show', 'me', 'hero', 'tv', 'review'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['infantry',
#   'mens',
#   'lume',
#   'dial',
#   'army',
#   'analog',
#   'quartz',
#   'wrist',
#   'watch',
#   'sport',
#   'blue',
#   'nylon',
#   'fabric',
#   'full'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['victorinox', 'swiss', 'army', 'date', 'womens', 'rubber', 'mop', 'watch'],
#  ['rt', 'indiakomuntorjawabdo', 'indian', 'army'],
#  ['seconds', 'summer', 'is', 'pick', 'fan', 'army'],
#  ['beyonce', 'is', 'pick', 'fan', 'army', 'beyhive'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['you',
#   'da',
#   'one',
#   'mtvsummerstar',
#   'videoveranomtv',
#   'mtvhottest',
#   'britney',
#   'spears',
#   'lana',
#   'del',
#   'rey'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['stony',
#   'jackson',
#   'americas',
#   'last',
#   'hope',
#   'leads',
#   'army',
#   'felons',
#   'thus',
#   'army',
#   'rejects',
#   'army',
#   'satan'],
#  ['wwi',
#   'wwii',
#   'japanese',
#   'army',
#   'navy',
#   'military',
#   'japan',
#   'leather',
#   'watch',
#   'war',
#   'mido',
#   'full',
#   'read',
#   'ebay'],
#  ['beyonce', 'is', 'pick', 'fan', 'army', 'beyhive'],
#  ['is', 'pick', 'fan', 'army', 'beyhive'],
#  ['beyonce', 'is', 'pick', 'fan', 'army', 'beyhive'],
#  ['is', 'pick', 'fan', 'army', 'beyhive'],
#  ['potus',
#   'appoints',
#   'brig',
#   'gen',
#   'richard',
#   'g',
#   'kaiser',
#   'member',
#   'mississippi',
#   'river',
#   'commission',
#   'learn',
#   'mrc'],
#  ['ap',
#   'violent',
#   'country',
#   'get',
#   'army',
#   'involved',
#   'help',
#   'control',
#   'killings',
#   'bring',
#   'back',
#   'peace',
#   'poor',
#   'people'],
#  ['wwi',
#   'wwii',
#   'japanese',
#   'army',
#   'navy',
#   'military',
#   'japan',
#   'leather',
#   'watch',
#   'war',
#   'mido',
#   'full',
#   'read',
#   'ebay'],
#  ['wwi',
#   'wwii',
#   'japanese',
#   'army',
#   'navy',
#   'military',
#   'japan',
#   'leather',
#   'watch',
#   'war',
#   'mido',
#   'full',
#   'read',
#   'ebay'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['two',
#   'jewish',
#   'terrorists',
#   'charged',
#   'in',
#   'historicchurch',
#   'arson',
#   'the',
#   'ugly',
#   'truth'],
#  ['spokane',
#   'authorities',
#   'say',
#   'theyre',
#   'struggling',
#   'solve',
#   'arson',
#   'cases',
#   'like',
#   'todays',
#   'hamilton'],
#  ['thousands',
#   'attend',
#   'rally',
#   'organized',
#   'peace',
#   'now',
#   'protesting',
#   'arson',
#   'attack',
#   'took',
#   'life'],
#  ['add', 'familia', 'arson', 'squad'],
#  ['another',
#   'fake',
#   'hate',
#   'crime',
#   'lesbians',
#   'burn',
#   'house',
#   'what',
#   'else',
#   'is',
#   'new'],
#  ['los',
#   'angeles',
#   'times',
#   'arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'newsintweets'],
#  ['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'israel'],
#  ['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'israel'],
#  ['the', 'sound', 'arson'],
#  ['owner', 'chicagoarea', 'gay', 'bar', 'admits', 'arson', 'scheme', 'lgbt'],
#  ['wait', 'what'],
#  ['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'],
#  ['trial', 'date', 'set', 'man', 'charged', 'arson', 'burglary'],
#  ['after',
#   'death',
#   'palestinian',
#   'toddler',
#   'arson',
#   'attack',
#   'israel',
#   'cracks',
#   'jewish'],
#  ['palestinian',
#   'teen',
#   'killed',
#   'amid',
#   'protests',
#   'against',
#   'arson',
#   'attack'],
#  ['kisii',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'failed',
#   'arson',
#   'plot',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'countynews'],
#  ['mariah', 'getting', 'thick', 'shoulders', 'poor', 'girl'],
#  ['mourning',
#   'notices',
#   'stabbing',
#   'arson',
#   'victims',
#   'stir',
#   'israel',
#   'posters',
#   'shira',
#   'banki',
#   'a'],
#  ['relaxinpr',
#   'miprv',
#   'rt',
#   'latimes',
#   'arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'california'],
#  ['jewish',
#   'leaders',
#   'prayed',
#   'hospital',
#   'palestinian',
#   'family',
#   'treated',
#   'arson',
#   'via',
#   'huffpostrelig'],
#  ['owner',
#   'chicagoarea',
#   'gay',
#   'bar',
#   'admits',
#   'arson',
#   'scheme',
#   'via',
#   'theadvocatemag',
#   'lgbt'],
#  ['saynae', 'angel', 'arson'],
#  ['kisii',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'failed',
#   'arson',
#   'plot',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'countynews'],
#  ['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'israel'],
#  ['owner',
#   'chicagoarea',
#   'gay',
#   'bar',
#   'admits',
#   'arson',
#   'scheme',
#   'via',
#   'theadvocatemag',
#   'lgbt'],
#  ['owner', 'chicagoarea', 'gay', 'bar', 'admits', 'arson', 'scheme', 'lgbt'],
#  ['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'israel'],
#  ['owner', 'chicagoarea', 'gay', 'bar', 'admits', 'arson', 'scheme', 'lgbt'],
#  ['arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'california',
#   'via',
#   'latimes'],
#  ['tennessee',
#   'lesbian',
#   'couple',
#   'faked',
#   'hate',
#   'crime',
#   'destroyed',
#   'home',
#   'lesbian'],
#  ['arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'california',
#   'los',
#   'angeles',
#   'times'],
#  ['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'],
#  ['cloudygoldrush', 'hate', 'white', 'people', 'mo'],
#  ['nowplaying', 'arsonist', 'mc', 'so', 'impressed', 'arsonistmusic'],
#  ['alleged', 'east', 'bay', 'serial', 'arsonist', 'arrested'],
#  ['safyuan',
#   'minor',
#   'citation',
#   'possesion',
#   'decriminalized',
#   'substance',
#   'im',
#   'facing',
#   'time'],
#  ['suspected', 'serial', 'arsonist', 'arrested', 'calif'],
#  ['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'],
#  ['localarsonist', 'diamorfiend', 'legal', 'system', 'never', 'forgets'],
#  ['casperrmg', 'u', 'dick'],
#  ['bloorossington',
#   'arsonist',
#   'also',
#   'burned',
#   'mattress',
#   'northumberland',
#   'st',
#   'cbcto'],
#  ['wheres', 'my', 'arsonist', 'at'],
#  ['if', 'dont', 'anything', 'nice', 'say', 'come', 'sit'],
#  ['vegetarian',
#   'vegan',
#   'video',
#   'shows',
#   'arsonist',
#   'torching',
#   'popular',
#   'bk',
#   'restaurant',
#   'strictly',
#   'vegetarian',
#   'govegan',
#   'uniteblue'],
#  ['arsonist',
#   'arrested',
#   'setting',
#   'many',
#   'fires',
#   'watch',
#   'headlines',
#   'nightbeat',
#   'veronicadlcruz'],
#  ['video',
#   'captures',
#   'man',
#   'removing',
#   'american',
#   'flag',
#   'from',
#   'long',
#   'beach',
#   'ca',
#   'home',
#   'burning',
#   'it',
#   'arsonist',
#   'sought'],
#  ['trick', 'think', 'nasty', 'things'],
#  ['spotlight',
#   'take',
#   'me',
#   'to',
#   'paradise',
#   'arsonist',
#   'mc',
#   'wniagospel',
#   'arsonistmusic'],
#  ['makes'],
#  ['town', 'salem', 'melted', 'ice', 'cube', 'bc', 'im', 'arsonist', 'd'],
#  ['arsonists',
#   'blamed',
#   'blaze',
#   'plastics',
#   'recycling',
#   'business',
#   'adelaide',
#   'reports'],
#  ['hotboy', 'shit'],
#  ['zodiac',
#   'girl',
#   'feat',
#   'trey',
#   'dupree',
#   'produced',
#   'by',
#   'sparkz',
#   'beatz',
#   'chuck',
#   'da',
#   'arsonist'],
#  ['localarsonist', 'lmfao'],
#  ['alleged', 'east', 'bay', 'serial', 'arsonist', 'arrested', 'sanfrancisco'],
#  ['doofus', 'diamorfiend', 'im', 'jokin', 'still', 'cant', 'moves'],
#  ['localarsonist', 'i', 'guess', 'u', 'say', 'shit', 'i', 'thinking'],
#  ['arsonist',
#   'sets',
#   'nyc',
#   'vegetarian',
#   'restaurant',
#   'fire',
#   'police',
#   'newyork'],
#  ['i',
#   'liked',
#   'youtube',
#   'video',
#   'slimebeast',
#   'town',
#   'salem',
#   'how',
#   'win',
#   'the',
#   'arsonist'],
#  ['casperrmg', 'bestcomedyvine', 'whats', 'cracking', 'cuz'],
#  ['smoke',
#   'good',
#   'fuck',
#   'eat',
#   'drink',
#   'drive',
#   'nice',
#   'car',
#   'wear',
#   'green',
#   'mink'],
#  ['kill', 'got', 'court', 'day', 'earl'],
#  ['localarsonist', 'lmao', 'real', 'live', 'go'],
#  ['owner',
#   'chicagoarea',
#   'gay',
#   'bar',
#   'admits',
#   'arson',
#   'scheme',
#   'frank',
#   'elliott',
#   'pleaded',
#   'guilty',
#   'hiring',
#   'arsonist'],
#  ['trusting',
#   'iran',
#   'stop',
#   'terrorism',
#   'like',
#   'inviting',
#   'arsonist',
#   'join',
#   'fire',
#   'brigade',
#   'telegraph'],
#  ['big',
#   'top',
#   'burning',
#   'the',
#   'true',
#   'story',
#   'of',
#   'an',
#   'arsonist',
#   'a',
#   'missing',
#   'girl'],
#  ['stay',
#   'vigilent',
#   'civil',
#   'liberties',
#   'constant',
#   'attack',
#   'nativehuman',
#   'myreligion'],
#  ['credit', 'pfannebeckers', 'inspiring', 'rediscover', 'fantabulous', 'tbt'],
#  ['nashville',
#   'theater',
#   'attack',
#   'will',
#   'gun',
#   'grabbers',
#   'now',
#   'demand'],
#  ['breaking', 'terror', 'attack', 'on', 'police', 'post', 'udhampur'],
#  ['demi',
#   'stans',
#   'really',
#   'think',
#   'heart',
#   'attack',
#   'sold',
#   'million',
#   'copies'],
#  ['scares',
#   'theres',
#   'new',
#   'versions',
#   'nuclear',
#   'attack',
#   'warnings',
#   'like',
#   'knowing',
#   'governments',
#   'still',
#   'prepare'],
#  ['isil',
#   'claims',
#   'suicide',
#   'bombing',
#   'saudi',
#   'mosque',
#   'killed',
#   'least'],
#  ['dattomm', 'funniest', 'part', 'twitter', 'feminists', 'try', 'attack'],
#  ['horrific', 'attack', 'wife', 'muslim', 'italy', 'liveleak', 'news'],
#  ['blasts',
#   'accused',
#   'yeda',
#   'yakub',
#   'dies',
#   'karachi',
#   'heart',
#   'attack',
#   'mumbai'],
#  ['etribune',
#   'us',
#   'drone',
#   'attack',
#   'kills',
#   'militants',
#   'north',
#   'waziristan',
#   'acebreakingnews'],
#  ['suspect', 'latest', 'theater', 'attack', 'psychological', 'issues'],
#  ['militants',
#   'attack',
#   'police',
#   'post',
#   'udhampur',
#   'spos',
#   'injured',
#   'livemint',
#   'allthenews'],
#  ['breaking',
#   'obama',
#   'officials',
#   'gave',
#   'muslim',
#   'terrorist',
#   'weapon',
#   'used',
#   'texas',
#   'attack'],
#  ['delhi',
#   'government',
#   'provide',
#   'free',
#   'treatment',
#   'acid',
#   'attack',
#   'victims',
#   'private',
#   'hospitals'],
# ...
#   'receive',
#   'blood',
#   'well'],
#  ['doing',
#   'dialyses',
#   'grandpa',
#   'oh',
#   'lord',
#   'blood',
#   'makes',
#   'light',
#   'headed'],
#  ['setzorah',
#   'dad',
#   'dont',
#   'claim',
#   'mean',
#   'right',
#   'look',
#   'eyes',
#   'blood',
#   'xbox',
#   'smh'],
#  ['omron',
#   'automatic',
#   'blood',
#   'pressure',
#   'monitor',
#   'standard',
#   'and',
#   'large',
#   'bp',
#   'cuffs'],
#  ['my', 'blood', 'pressure', 'roof', 'i', 'dont', 'need', 'extra', 'shit'],
#  ['chamberedblood', 'yeah', 'speakingfromexperience'],
#  ['cant',
#   'believe',
#   'people',
#   'mid',
#   'dont',
#   'high',
#   'blood',
#   'pressure',
#   'life',
#   'stressful',
#   'decisionsondecisions'],
#  ['guys', 'i', 'imouto', 'who', 'isnt', 'actually', 'related', 'me', 'blood'],
#  ['bruh',
#   'white',
#   'people',
#   'buy',
#   'ugliest',
#   'shoes',
#   'super',
#   'tight',
#   'blood',
#   'going',
#   'feet'],
#  ['another',
#   'day',
#   'another',
#   'excellent',
#   'dangerousbeans',
#   'porridge',
#   'seriously',
#   'people',
#   'blood',
#   'orange',
#   'porridge',
#   'phenomenal'],
#  ['happy', 'birthday', 'young', 'blood'],
#  ['if', 'wasnt', 'blood'],
#  ['no', 'kinda', 'shii', 'nasty', 'blood', 'no', 'pun', 'intended'],
#  ['aint', 'hoe', 'blood'],
#  ['today',
#   'hastle',
#   'getting',
#   'drug',
#   'tested',
#   'blood',
#   'drown',
#   'tb',
#   'shot',
#   'document',
#   'filling'],
#  ['man',
#   'somebody',
#   'got',
#   'ta',
#   'stop',
#   'sbee',
#   'dude',
#   'fuckin',
#   'funny',
#   'blood'],
#  ['where', 'winds', 'take', 'gypsy', 'blood', 'time'],
#  ['loboparanoico', 'mad', 'men'],
#  ['private', 'thirsty', 'nightsad', 'blood', 'rockn', 'roll'],
#  ['rolandonabeats',
#   'ellie',
#   'goulding',
#   'my',
#   'blood',
#   'acesse',
#   'nosso',
#   'site',
#   'para',
#   'ouvir'],
#  ['olrules',
#   'welcome',
#   'read',
#   'free',
#   'chapter',
#   'new',
#   'book',
#   'encounters',
#   'with',
#   'jesus',
#   'its',
#   'full',
#   'hope'],
#  ['anthxvy', 'runs', 'blood'],
#  ['sethalphaeus',
#   'personal',
#   'favorites',
#   'include',
#   'paramore',
#   'muse',
#   'green',
#   'day',
#   'royal',
#   'blood'],
#  ['shed',
#   'innocent',
#   'blood',
#   'sons',
#   'daughters',
#   'land',
#   'polluted',
#   'psalms',
#   'help',
#   'stop',
#   'sin',
#   'abortion'],
#  ['se', 'pone', 'cantar', 'crying', 'lightning'],
#  ['wasnt',
#   'big',
#   'stab',
#   'deep',
#   'stab',
#   'theres',
#   'like',
#   'blood',
#   'everwhe'],
#  ['add',
#   'items',
#   'everyday',
#   'eating',
#   'habits',
#   'please',
#   'research',
#   'take'],
#  ['looooooooooool', 'bloody', 'hell'],
#  ['infected', 'bloody', 'ear', 'piercings', 'always', 'fun'],
#  ['aggressif', 'bloody', 'aggressive'],
#  ['i',
#   'entered',
#   'win',
#   'entire',
#   'set',
#   'butterlondon',
#   'lip',
#   'crayons',
#   'via',
#   'go',
#   'enter',
#   'bbloggers'],
#  ['slsandpet',
#   'hey',
#   'sally',
#   'sorry',
#   'emailed',
#   'been',
#   'awol',
#   'bloody',
#   'work',
#   'argh',
#   'resigninshame'],
#  ['im', 'listening', 'bloody', 'jay'],
#  ['lauradeholanda',
#   'i',
#   'forrest',
#   'version',
#   'thats',
#   'bloody',
#   'awful',
#   'well',
#   'xxx'],
#  ['a', 'nightmare', 'on', 'elm', 'street', 'is', 'getting', 'remade', 'again'],
#  ['i',
#   'cant',
#   'bloody',
#   'wait',
#   'sony',
#   'sets',
#   'date',
#   'for',
#   'stephen',
#   'dark',
#   'stephenking',
#   'thedarktower',
#   'bdisgusting'],
#  ['got', 'ta', 'try', 'let', 'go', 'many', 'bloody', 'things', 'smh'],
#  ['tradcatknight',
#   'russia',
#   'may',
#   'played',
#   'reason',
#   'link',
#   'bs',
#   'okanowa',
#   'bloody',
#   'mainline',
#   'invasion',
#   'looked',
#   'like',
#   'bloody'],
#  ['bloody', 'insomnia', 'grrrr', 'insomnia'],
#  ['zhenghxn',
#   'tried',
#   'eyes',
#   'akame',
#   'ga',
#   'kill',
#   'tokyo',
#   'ghoul',
#   'damn',
#   'bloody',
#   'dont',
#   'dare',
#   'watch'],
#  ['fantosex',
#   'now',
#   'suck',
#   'thats',
#   'youre',
#   'bloody',
#   'getting',
#   'means',
#   'amends'],
#  ['you',
#   'call',
#   'weekends',
#   'i',
#   'call',
#   'bloody',
#   'mary',
#   'times',
#   'this',
#   'summers',
#   'full',
#   'my'],
#  ['bloody',
#   'hell',
#   'day',
#   'i',
#   'havent',
#   'even',
#   'really',
#   'done',
#   'anything',
#   'just',
#   'tired',
#   'of',
#   'everything',
#   'thought',
#   'vaca',
#   'would',
#   'help',
#   'much'],
#  ['damn', 'bloody', 'hot'],
#  ['mrtophypup', 'bloody', 'sexy', 'drools'],
#  ['you',
#   'know',
#   'say',
#   'side',
#   'effects',
#   'low',
#   'amp',
#   'really',
#   'fast',
#   'son',
#   'product',
#   'acne',
#   'cream',
#   'why',
#   'side',
#   'effects',
#   'bloody',
#   'diarrhea'],
#  ['ronda',
#   'rousey',
#   'would',
#   'close',
#   'making',
#   'floyd',
#   'mayweathers',
#   'money',
#   'fights',
#   'bloody',
#   'elbow',
#   'boxing'],
#  ['im',
#   'awful',
#   'painting',
#   'i',
#   'agree',
#   'landscape',
#   'bloody',
#   'oils',
#   'paints'],
#  ['all',
#   'i',
#   'need',
#   'life',
#   'sin',
#   'is',
#   'girlfriend',
#   'down',
#   'ride',
#   'till',
#   'bloody',
#   'end',
#   'just',
#   'girlfriend'],
#  ['itsmegss', 'i', 'think', 'well', 'bloody', 'barking'],
#  ['eh',
#   'hello',
#   'cover',
#   'bloody',
#   'thighs',
#   'bloody',
#   'cleav',
#   'eh',
#   'hello',
#   'since',
#   'expose',
#   'cleavage'],
#  ['johnjcampbell', 'mega', 'bloody', 'marvellous'],
#  ['bloody', 'mary', 'sink', 'beet', 'juice'],
#  ['melrises',
#   'wwwbigbaldhead',
#   'jessienojoke',
#   'monty',
#   'python',
#   'date',
#   'bloody',
#   'far',
#   'wants',
#   'go'],
#  ['meet', 'bloody'],
#  ['friday', 'supposed', 'happy', 'day', 'bloody', 'friday', 'hah', 'zzzz'],
#  ['chxrmingprince',
#   'jonesluna',
#   'i',
#   'bloody',
#   'hope',
#   'said',
#   'folding',
#   'arms',
#   'sitting',
#   'back',
#   'chair'],
#  ['wait',
#   'tell',
#   'college',
#   'friend',
#   'reafs',
#   'bloody',
#   'mary',
#   'drama',
#   'cd'],
#  ['i',
#   'came',
#   'kill',
#   'indiansfor',
#   'fun',
#   'video',
#   'smirking',
#   'remorseless',
#   'pakistani',
#   'killer',
#   'shows',
#   'boasting'],
#  ['ive',
#   'watched',
#   'episode',
#   'bloody',
#   'monday',
#   'bloodymonday',
#   'tvshowtime'],
#  ['marlon',
#   'williams',
#   'gt',
#   'elvis',
#   'presley',
#   'gt',
#   'marlon',
#   'williams',
#   'gt',
#   'steel',
#   'panther',
#   'shuffle',
#   'mode',
#   'like',
#   'bloody',
#   'legend'],
#  ['black',
#   'friday',
#   'turns',
#   'bloody',
#   'would',
#   'rather',
#   'shopping',
#   'mystery'],
#  ['ezralevant',
#   'someone',
#   'told',
#   'soccer',
#   'moms',
#   'getting',
#   'pic',
#   'blown',
#   'put',
#   'daughters',
#   'bedroom',
#   'walls',
#   'not'],
#  ['papcrdoll',
#   'i',
#   'mentions',
#   'get',
#   'blown',
#   'my',
#   'choice',
#   'i',
#   'deactivate',
#   'leave',
#   'good',
#   'respect',
#   'my',
#   'choices'],
#  ['manutd',
#   'emilymcfcheslop',
#   'wow',
#   'wow',
#   'if',
#   'club',
#   'blown',
#   'money',
#   'fucked',
#   'player',
#   'like',
#   'theyd',
#   'pilloried'],
#  ['damn', 'greinke', 'got', 'blown', 'first', 'inning'],
#  ['woke', 'blown', 'lol'],
#  ['aunt', 'marge', 'youre', 'blown', 'eheks'],
#  ['troylercraft',
#   'yeah',
#   'its',
#   'not',
#   'worth',
#   'it',
#   'bc',
#   'he',
#   'already',
#   'has',
#   'so',
#   'many',
#   'spammers',
#   'amp',
#   'his',
#   'twitter',
#   'is',
#   'probably',
#   'blown',
#   'up',
#   'every',
#   'second'],
#  ['white',
#   'family',
#   'supposedly',
#   'representing',
#   'americas',
#   'great',
#   'values',
#   'gets',
#   'blown',
#   'horrible',
#   'cgi',
#   'nuclear',
#   'strike',
#   'lmfaoooo'],
#  ['man', 'hasnt', 'machinegunkelly', 'blown', 'hes', 'still', 'underground'],
#  ['and', 'mentions', 'blown', 'wtf'],
#  ['on',
#   'thisdayinhistory',
#   'confederate',
#   'ship',
#   'blown',
#   'crew',
#   'read',
#   'more',
#   'via',
#   'history'],
#  ['that',
#   'moment',
#   'ur',
#   'win',
#   'mini',
#   'uhc',
#   'get',
#   'blown',
#   'creeper',
#   'get',
#   'kicked',
#   'flying',
#   'so',
#   'salty',
#   'rn'],
#  ['libraryeliza',
#   'get',
#   'bump',
#   'approval',
#   'probably',
#   'hes',
#   'blown',
#   'musicadvisory'],
#  ['if',
#   'truckload',
#   'soldiers',
#   'blown',
#   'nobody',
#   'panics',
#   'one',
#   'little',
#   'lion',
#   'dies',
#   'everyone',
#   'loses',
#   'mind'],
#  ['hey',
#   'look',
#   'kashs',
#   'foundation',
#   'live',
#   'today',
#   'got',
#   'blown',
#   'people',
#   'magazines',
#   'website',
#   'todd',
#   'blake'],
#  ['got',
#   'last',
#   'month',
#   'i',
#   'went',
#   'ee',
#   'shop',
#   'glad',
#   'hasnt',
#   'blown',
#   'yet'],
#  ['first', 'time', 'tweet', 'blown', 'almost', 'half', 'day', 'later', 're'],
#  ['blown', 'away', 'extension', 'nothing', 'seen', 'many', 'options', 'one'],
#  ['theboyofmasks',
#   'thanks',
#   'letting',
#   'stay',
#   'since',
#   'manor',
#   'blown',
#   'anyways',
#   'buddy'],
#  ['loner',
#   'diaries',
#   'the',
#   'patterns',
#   'sand',
#   'may',
#   'blown',
#   'away',
#   'the',
#   'photos',
#   'twos',
#   'all',
#   'choked',
#   'flames'],
#  ['even',
#   'though',
#   'bsg',
#   'sufficiently',
#   'hyped',
#   'years',
#   'i',
#   'somehow',
#   'delayed',
#   'watching',
#   'i',
#   'utterly',
#   'utterly',
#   'blown',
#   'away'],
#  ['vanessas',
#   'game',
#   'officially',
#   'blown',
#   'ladies',
#   'and',
#   'gentlementhe',
#   'real',
#   'show',
#   'begin'],
#  ['guaranteed',
#   'bitten',
#   'mutant',
#   'mosquito',
#   'ankle',
#   'blown',
#   'little',
#   'cunts'],
#  ['things',
#   'can',
#   'pick',
#   'tozlet',
#   'seat',
#   'butt',
#   'leprosy',
#   'fullblown',
#   'jerkface',
#   'syndrome',
#   'lateral',
#   'lisp',
#   'amp',
#   'toilet',
#   'rickets'],
#  ['kalinandmyles',
#   'kalinwhite',
#   'ig',
#   'blown',
#   'hackers',
#   'i',
#   'need',
#   'stop',
#   'givebackkalinwhiteaccount'],
#  ['lukewinkie',
#   'whoever',
#   'directing',
#   'videos',
#   'needs',
#   'grab',
#   'nicki',
#   'minaj',
#   'someone',
#   'us',
#   'recognition',
#   'minds',
#   'blown'],
#  ['princessduck',
#   'last',
#   'week',
#   'wanted',
#   'sense',
#   'get',
#   'blown',
#   'far',
#   'good',
#   'james',
#   'could',
#   'win',
#   'hes',
#   'huge',
#   'target',
#   'gone',
#   'soon'],
#  ['orbette', 'like', 'blown', 'up', 'amirite'],
#  ['my', 'blown', 'kennel', 'bloody', 'yorkshire', 'terrorist'],
#  ['turn', 'get', 'blown'],
#  ['hopefulbatgirl',
#   'went',
#   'i',
#   'beaten',
#   'blown',
#   'then',
#   'next',
#   'thing',
#   'i',
#   'know',
#   'ra',
#   'al',
#   'ghul',
#   'brought',
#   'back',
#   'life',
#   'i',
#   'escaped'],
#  ['thebriankrause',
#   'leos',
#   'ass',
#   'got',
#   'metaphorically',
#   'blown',
#   'piperwearsthepants',
#   'charmed'],
#  ['anarchicteapot',
#   'boironusa',
#   'glononium',
#   'also',
#   'helps',
#   'blown',
#   'bashing',
#   'bottle',
#   'nitroglycerin',
#   'book'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full'],
#  ['if',
#   'son',
#   'daughter',
#   'would',
#   'like',
#   'see',
#   'going',
#   'war',
#   'iran',
#   'come',
#   'back',
#   'body',
#   'bag',
#   'let',
#   'republicans',
#   'know'],
#  ['questergirl',
#   'ditto',
#   'way',
#   'feel',
#   'drank',
#   'vodka',
#   'ice',
#   'would',
#   'body',
#   'bag'],
#  ['handbags',
#   'genuine',
#   'mulberry',
#   'antony',
#   'cross',
#   'body',
#   'messenger',
#   'bag',
#   'dark',
#   'oak',
#   'soft',
#   'buffalo',
#   'leather',
#   'date',
#   'w'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['louis',
#   'vuitton',
#   'cultsierre',
#   'monogram',
#   'shoulder',
#   'bag',
#   'cross',
#   'body',
#   'bag'],
#  ['check',
#   'ameribag',
#   'healthy',
#   'back',
#   'bag',
#   'shoulder',
#   'cross',
#   'body',
#   'backpack',
#   'khaki',
#   'tan',
#   'beige',
#   'nylon',
#   'ebay'],
#  ['photo',
#   'bath',
#   'amp',
#   'body',
#   'works',
#   'cosmetic',
#   'bag',
#   'periwinkle',
#   'blue',
#   'copper',
#   'piping',
#   'along',
#   'top',
#   'four',
#   'corners'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'body',
#   'bag',
#   'hip',
#   'a',
#   'word',
#   'skirt',
#   'blue'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'rt'],
#  ['trjdavis',
#   'bruh',
#   'wan',
#   'na',
#   'fight',
#   'im',
#   'meet',
#   'cage',
#   'bro',
#   'better',
#   'find',
#   'youre',
#   'dealing',
#   'end',
#   'body',
#   'bag'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'full'],
#  ['auth',
#   'louis',
#   'vuitton',
#   'brown',
#   'saumur',
#   'cross',
#   'body',
#   'shoulder',
#   'bag',
#   'monogram',
#   'full'],
#  ['check',
#   'vintage',
#   'longaberger',
#   'floral',
#   'fabric',
#   'shoulder',
#   'cross',
#   'body',
#   'bag',
#   'brown',
#   'leather',
#   'strap',
#   'ebay'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'body',
#   'bag',
#   'hip',
#   'a',
#   'word',
#   'skirt',
#   'blue'],
#  ['ìü',
#   'new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'rt'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['new',
#   'women',
#   'handbag',
#   'faux',
#   'leather',
#   'ladies',
#   'shoulder',
#   'tote',
#   'cross',
#   'body',
#   'bag',
#   'large',
#   'satchel',
#   'full'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['one', 'day', 'heart', 'gone', 'get', 'zipped', 'body', 'bag'],
#  ['handbag',
#   'fashion',
#   'style',
#   'authentic',
#   'louis',
#   'vuitton',
#   'pochette',
#   'bosphore',
#   'shoulder',
#   'cross',
#   'body'],
#  ['å',
#   'new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['handbag',
#   'fashion',
#   'style',
#   'vintage',
#   'coach',
#   'purse',
#   'camera',
#   'bag',
#   'cross',
#   'body',
#   'bids'],
#  ['genuine',
#   'leather',
#   'man',
#   'bag',
#   'messenger',
#   'fit',
#   'ipad',
#   'mini',
#   'tablet',
#   'case',
#   'cross',
#   'body',
#   'air',
#   'jp',
#   'full'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['nuu', 'fam', 'fwt', 'im', 'leave', 'you', 'in', 'body', 'bag'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'full'],
#  ['deliciousvomit',
#   'no',
#   'im',
#   'im',
#   'saying',
#   'theyre',
#   'lucky',
#   'go',
#   'home',
#   'families',
#   'put',
#   'body',
#   'bag'],
#  ['mattbez',
#   'oh',
#   'im',
#   'bagging',
#   'her',
#   'body',
#   'bangin',
#   'im',
#   'saying',
#   'shes',
#   'going',
#   'get',
#   'rose'],
#  ['ohmyloz', 'rondarousey', 'bagging', 'body', 'shes', 'smoking', 'hot'],
#  ['drake', 'really', 'body', 'bagging', 'meek'],
#  ['fuckyeahcarey',
#   'bornverified',
#   'drake',
#   'killing',
#   'dude',
#   'tea',
#   'bagging',
#   'dead',
#   'body',
#   'point'],
#  ['meekmill',
#   'wreck',
#   'league',
#   'ball',
#   'drake',
#   'olympic',
#   'level',
#   'body',
#   'bagging',
#   'like',
#   'career',
#   'nothing',
#   'trollingtilmeekdiss'],
#  ['idgaf',
#   'tough',
#   'canada',
#   'north',
#   'philly',
#   'meek',
#   'acting',
#   'like',
#   'bitch',
#   'amp',
#   'drake',
#   'body',
#   'bagging',
#   'ass',
#   'tracks'],
#  ['yankees', 'body', 'bagging', 'mfs'],
#  ['broseidonrex',
#   'dapurplesharpie',
#   'i',
#   'skimmed',
#   'twitter',
#   'missed',
#   'body',
#   'bagging'],
#  ['g', 'body', 'bagging', 'lyrically'],
#  ['bomairinge', 'elutranscendent', 'straight', 'body', 'bagging'],
#  ['body', 'bagging', 'bitches'],
#  ['no',
#   'better',
#   'feeling',
#   'seeing',
#   'stage',
#   'day',
#   'ones',
#   'year',
#   'friendships',
#   'still',
#   'body',
#   'bagging',
#   'mics',
#   'together'],
#  ['mopheme',
#   'bigstar',
#   'johnson',
#   'problem',
#   'game',
#   'body',
#   'bagging',
#   'niggas',
#   'vuzuhustle'],
#  ['i', 'body', 'bagging', 'post', 'score'],
#  ['editaxohaze',
#   'let',
#   'bagging',
#   'bodys',
#   'begin',
#   'lol',
#   'i',
#   'aint',
#   'cuffed',
#   'yet',
#   'shouldnt',
#   'bad'],
#  ...]

# %%
embedding_dict={}
with open('../input/glove-global-vectors-for-word-representation/glove.6B.100d.txt','r') as f:
    for line in f:
        values=line.split()
        word=values[0]
        vectors=np.asarray(values[1:],'float32')
        embedding_dict[word]=vectors
f.close()

# %%
MAX_LEN=50
tokenizer_obj=Tokenizer()
tokenizer_obj.fit_on_texts(corpus)
sequences=tokenizer_obj.texts_to_sequences(corpus)

tweet_pad=pad_sequences(sequences,maxlen=MAX_LEN,truncating='post',padding='post')

# %%
sequences

# %%
tweet_pad

# %%
word_index=tokenizer_obj.word_index
print('Number of unique words:',len(word_index))

# %%
num_words=len(word_index)+1
embedding_matrix=np.zeros((num_words,100))

for word,i in tqdm(word_index.items()):
    if i > num_words:
        continue
    
    emb_vec=embedding_dict.get(word)
    if emb_vec is not None:
        embedding_matrix[i]=emb_vec

# %%
num_words

# %%
embedding_matrix

# %%
print(emb_vec)

# %% [markdown]
# ## Baseline Model

# %%
model=Sequential()

embedding=Embedding(num_words,100,embeddings_initializer=Constant(embedding_matrix),
                   input_length=MAX_LEN,trainable=False)

model.add(embedding)
model.add(SpatialDropout1D(0.2))
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))


optimzer=Adam(learning_rate=1e-5)

model.compile(loss='binary_crossentropy',optimizer=optimzer,metrics=['accuracy'])

# %%
model.summary()

# %%
tweet.shape[0]

# %%
train=tweet_pad[:tweet.shape[0]]
test=tweet_pad[tweet.shape[0]:]

# %%
train

# %%
test

# %%
X_train,X_test,y_train,y_test=train_test_split(train,tweet['target'].values,test_size=0.15)
print('Shape of train',X_train.shape)
print("Shape of Validation ",X_test.shape)

# %%
history=model.fit(X_train,y_train,batch_size=4,epochs=15,validation_data=(X_test,y_test),verbose=2)
